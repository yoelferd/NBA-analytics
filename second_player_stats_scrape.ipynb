# %%
import time
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from basketball_reference_web_scraper import client
from datetime import date
from functools import reduce
from datetime import datetime
from collections import Counter
from dateutil.rrule import rrule, DAILY
from basketball_reference_web_scraper import client
from basketball_reference_web_scraper.data import Team
from basketball_reference_web_scraper.data import Outcome
from basketball_reference_web_scraper.data import Position

# %%
'''
NOTE: This section of code is *adapted* from https://github.com/stevenrdungan/mvp.
It downloads NBA MVP voting data from basketball reference using web scraping.
# Runtime 1-2 minutes
I will take this voting data and build a regression model using my leaders dataset created above to test whether
leading one's team the most per season in stats in each game is a good predictor for MVP votes.
'''

import os
from bs4 import BeautifulSoup
import requests
import csv

def get_response(url):
    print(f"Requesting \'{url}\'")
    try:
        r = requests.get(url)
        text = r.text
        return BeautifulSoup(text, 'lxml')
    except requests.exceptions.RequestException as e:
        print(e)
    return None

# create directory for data
directory = os.path.join(os.getcwd(), 'scrapedata')
print(f"directory is '{directory}'")
if not os.path.exists(directory):
    print(f"Creating directory \'{directory}\'")
    os.makedirs(directory)

# scrape player per game statistic data 1988-2019
for year in range(1988,2020):
    data = []
    url = f"http://www.basketball-reference.com/leagues/NBA_{year}_per_game.html"
    soup = get_response(url)
    table = soup.find('table', attrs={'id':'per_game_stats'})
    table_head = table.find('thead')
    hrow = table_head.find('tr')
    hcols = hrow.find_all('th')
    hcols = [ele.text.strip() for ele in hcols]
    data.append([ele for ele in hcols if ele])
    table_body = table.find('tbody')
    rows = table_body.find_all('tr')
    for row in rows:
        cols = [ele.text.strip() for ele in row.find_all('th')]
        # ignore rows that contain header information
        if cols[0] == 'Rk':
            continue
        cols += [ele.text.strip() for ele in row.find_all('td')]
        # data.append([ele for ele in cols if ele])
        # occasionally records representing pct are blank if num and denom are zero
        data.append([ele for ele in cols])
    fname = f"{directory}/{table.get('id')}_{year}.csv"
    with open(fname, 'w') as file:
        wr = csv.writer(file)
        wr.writerows(data)

# scrape player advanced statistic data 1988-2019
for year in range(1988,2020):
    data = []
    url = f"http://www.basketball-reference.com/leagues/NBA_{year}_advanced.html"
    soup = get_response(url)
    table = soup.find('table', attrs={'id':'advanced_stats'})
    table_head = table.find('thead')
    hrow = table_head.find('tr')
    hcols = hrow.find_all('th')
    hcols = [ele.text.strip() for ele in hcols]
    data.append([ele for ele in hcols if ele])
    table_body = table.find('tbody')
    rows = table_body.find_all('tr')
    for row in rows:
        cols = [ele.text.strip() for ele in row.find_all('th')]
        # ignore rows that contain header information
        if cols[0] == 'Rk':
            continue
        cols += [ele.text.strip() for ele in row.find_all('td')]
        data.append([ele for ele in cols if ele])
    fname = f"{directory}/{table.get('id')}_{year}.csv"
    with open(fname, 'w') as file:
        wr = csv.writer(file)
        wr.writerows(data)

#scrape MVP voting data 1988-2018
for year in range(1988,2019):
    data = []
    url = f"http://www.basketball-reference.com/awards/awards_{year}.html"
    soup = get_response(url)
    if not soup:
        continue
    table = soup.find('table', attrs={'id':'mvp'})
    table_head = table.find('thead')
    hrow = table_head.find_all('tr')[1]
    hcols = hrow.find_all('th')
    hcols = [ele.text.strip() for ele in hcols]
    data.append([ele for ele in hcols if ele])
    table_body = table.find('tbody')
    rows = table_body.find_all('tr')
    # because the 'Rank' column is broken we'll do it ourselves
    rank = 0
    for row in rows:
        rank += 1
        line = [rank]
        cols = [ele.text.strip() for ele in row.find_all('td')]
        line += [ele for ele in cols]
        data.append([ele for ele in line if ele])
    fname = f"{directory}/mvp_voting_{year}.csv"
    with open(fname, 'w') as file:
        wr = csv.writer(file)
        wr.writerows(data)

# scrape standings data 1988-2019
for year in range(1988,2020):
    url = f"http://www.basketball-reference.com/leagues/NBA_{year}_standings.html"
    soup = get_response(url)
    tables = soup.find_all('table')
    for table in tables:
        tid = table.get('id')
        data = []
        table_head = table.find('thead')
        hrow = table_head.find('tr')
        hcols = hrow.find_all('th')
        hcols = [ele.text.strip() for ele in hcols]
        data.append([ele for ele in hcols if ele])
        table_body = table.find('tbody')
        rows = table_body.find_all('tr')
        for row in rows:
            cols = [ele.text.strip() for ele in row.find_all('th')]
            cols += [ele.text.strip() for ele in row.find_all('td')]
            data.append([ele for ele in cols if ele])
        fname = f"{directory}/{tid}_{year}.csv"
        with open(fname, 'w') as file:
            wr = csv.writer(file)
            wr.writerows(data)
# Out:
# directory is '/Users/crazyforcandy1234/Desktop/Desktop_91117/Academics/Tutorials/Data_anal/NBA_MVP_LEADERSDATA/scrapedata'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1988_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1989_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1990_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1991_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1992_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1993_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1994_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1995_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1996_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1997_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1998_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1999_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2000_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2001_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2002_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2003_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2004_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2005_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2006_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2007_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2008_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2009_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2010_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2011_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2012_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2013_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2014_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2015_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2016_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2017_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2018_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2019_per_game.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1988_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1989_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1990_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1991_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1992_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1993_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1994_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1995_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1996_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1997_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1998_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1999_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2000_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2001_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2002_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2003_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2004_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2005_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2006_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2007_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2008_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2009_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2010_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2011_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2012_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2013_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2014_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2015_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2016_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2017_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2018_advanced.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2019_advanced.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_1988.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_1989.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_1990.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_1991.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_1992.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_1993.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_1994.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_1995.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_1996.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_1997.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_1998.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_1999.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_2000.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_2001.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_2002.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_2003.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_2004.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_2005.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_2006.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_2007.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_2008.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_2009.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_2010.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_2011.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_2012.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_2013.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_2014.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_2015.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_2016.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_2017.html'
# Requesting 'http://www.basketball-reference.com/awards/awards_2018.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1988_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1989_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1990_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1991_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1992_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1993_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1994_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1995_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1996_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1997_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1998_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_1999_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2000_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2001_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2002_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2003_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2004_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2005_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2006_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2007_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2008_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2009_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2010_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2011_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2012_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2013_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2014_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2015_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2016_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2017_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2018_standings.html'
# Requesting 'http://www.basketball-reference.com/leagues/NBA_2019_standings.html'

# %%
#Scraping top MVP candidates from the current year from https://www.basketball-reference.com/friv/mvp.html
url = f"https://www.basketball-reference.com/friv/mvp.html"
soup = get_response(url)
tables = soup.find_all('table')
for table in tables:
    tid = table.get('id')
    data = []
    table_head = table.find('thead')
    hrow = table_head.find('tr')
    hcols = hrow.find_all('th')
    hcols = [ele.text.strip() for ele in hcols]
    data.append([ele for ele in hcols if ele])
    table_body = table.find('tbody')
    rows = table_body.find_all('tr')
    for row in rows:
        cols = [ele.text.strip() for ele in row.find_all('th')]
        cols += [ele.text.strip() for ele in row.find_all('td')]
        data.append([ele for ele in cols if ele])
df=pd.DataFrame(data)
df.columns=df.iloc[0]
df=df.drop([0]).drop(columns=['Rk'])
df['Prob%'] = df['Prob%'].str.replace('%', '').astype(float)
cols = df.columns.drop(['Player','Tm'])
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')
df["Rank"]=df.index
df["Share"]=df["Prob%"]/58 #convert the given probability to match share

#create same directory
directory = os.path.join(os.getcwd(), 'scrapedata')
print(f"directory is '{directory}'")
if not os.path.exists(directory):
    print(f"Creating directory \'{directory}\'")
    os.makedirs(directory)

#format name the same
df.to_csv(f"{directory}/mvp_voting_2019.csv")
# Out:
# Requesting 'https://www.basketball-reference.com/friv/mvp.html'
# directory is '/Users/crazyforcandy1234/Desktop/Desktop_91117/Academics/Tutorials/Data_anal/NBA_MVP_LEADERSDATA/scrapedata'

# %%
import os
import re

'''
NOTE: This section of code is adapted from https://github.com/stevenrdungan/mvp

Merges all our scraped data together - MVP voting data, Per game data, Seed, Advanced stats

I'll use this to make MVP predictions. AND I hope to utilize All-Star data: take data from seasons up until the all star selection and use leaders dataset
to predict the binary all-star selection.
'''

teams = {'Atlanta Hawks':'ATL',
'Boston Celtics':'BOS',
'Brooklyn Nets':'BRK',
'Charlotte Bobcats':'CHA',
'Charlotte Hornets':'CHO',
'Chicago Bulls':'CHI',
'Cleveland Cavaliers':'CLE',
'Dallas Mavericks':'DAL',
'Denver Nuggets':'DEN',
'Detroit Pistons':'DET',
'Golden State Warriors':'GSW',
'Houston Rockets':'HOU',
'Indiana Pacers':'IND',
'Los Angeles Clippers':'LAC',
'Los Angeles Lakers':'LAL',
'Memphis Grizzlies':'MEM',
'Miami Heat':'MIA',
'Milwaukee Bucks':'MIL',
'Minnesota Timberwolves':'MIN',
'New Jersey Nets':'NJN',
'New Orleans Hornets':'NOH',
'New Orleans Pelicans':'NOP',
'New OrleansOklahoma City Hornets':'NOK',
'New York Knicks':'NYK',
'Oklahoma City Thunder':'OKC',
'Orlando Magic':'ORL',
'Philadelphia 76ers':'PHI',
'Phoenix Suns':'PHO',
'Portland Trail Blazers':'POR',
'Sacramento Kings':'SAC',
'San Antonio Spurs':'SAS',
'Seattle SuperSonics':'SEA',
'Toronto Raptors':'TOR',
'Utah Jazz':'UTA',
'Vancouver Grizzlies':'VAN',
'Washington Bullets':'WSB',
'Washington Wizards':'WAS'}

pd.set_option('precision', 3)
data = pd.DataFrame()   # this will be our dataset
directory = os.path.join(os.getcwd(),'scrapedata')

for year in range(1988,2020):
    # read data into DataFrames
    pergame, advanced, voting, east, west = pd.DataFrame(), pd.DataFrame(), pd.DataFrame(), pd.DataFrame(), pd.DataFrame()
    for filename in os.listdir(directory):
        if re.match(f"per_game_stats_{year}.csv", filename):
            pergame = pd.read_csv(os.path.join(directory,filename))
            if year == 2017:
                if 'PS/G' in pergame.columns:
                    pergame=pergame.rename(index=str, columns={"PS/G": "PTS"})
        elif re.match(f"advanced_stats_{year}.csv", filename):
            advanced = pd.read_csv(os.path.join(directory,filename))
        elif re.match(f"mvp_voting_{year}.csv", filename):
            voting = pd.read_csv(os.path.join(directory,filename))
        elif re.match(f"[a-z]+s_standings_E_{year}.csv", filename):
            east = pd.read_csv(os.path.join(directory,filename))
        elif re.match(f"[a-z]+s_standings_W_{year}.csv", filename):
            west = pd.read_csv(os.path.join(directory,filename))

    # assemble stats dataframe
    pergame = pergame.loc[:,['Player','Age','Tm','G','MP','TRB','AST','STL','BLK','PTS',"FGA",'FG%','3PA','3P%','eFG%','FT%','TOV','PF']]
    advanced = advanced.loc[:,['Player','Age','Tm','PER','TS%','USG%','VORP','WS','TRB%','AST%','STL%','BLK%','TOV%','WS/48','BPM']]
    if year == 2019:
        advanced["WS"]=advanced["WS"]*(82/pergame["G"].max())  #ADJUST WIN SHARE FOR FULL SEASON
        advanced["VORP"]=advanced["VORP"]*(82/pergame["G"].max())  #ADJUST WIN SHARE FOR FULL SEASON
    stats = pd.merge(pergame, advanced, on=['Player','Age','Tm'], how='left')
    stats['Year'] = year
    # remove asterisk symbol from player name (Hall of Famers)
    stats['Player'].replace(to_replace=r'\*', value=r'', regex=True, inplace=True)
    # drop all duplicate rows (i.e. players who played on multiple teams in same season)
    stats = stats.drop_duplicates(subset=['Player','Age'], keep=False)
    # only keep rows for players playing 25 minutes per game or more
    stats = stats[stats.MP >= 25.0]
    # box is sum of rebounds, assists, steals, blocks
    stats['box'] = stats['TRB'] + stats['AST'] + stats['STL'] + stats['BLK']

    # assemble standings dataframe. sort 2017 playoff teams can be easily determined
    east = east.rename(columns = {'Eastern Conference':'Tm'}).sort_values('W/L%', ascending=False).reset_index(drop=True)
    west = west.rename(columns = {'Western Conference':'Tm'}).sort_values('W/L%', ascending=False).reset_index(drop=True)
    # this will remove the Division/Conference header lines
    standings = pd.concat([east, west]).dropna()
    standings = standings.loc[:,['Tm','W','L','W/L%']]
    standings['playoffs'] = standings['Tm'].str.contains('\*').astype(int)
    standings['seed'] = standings.index + 1

    if year == 2019:
        standings['playoffs'][standings.index < 8] = 1   # assume playoffs for top 8 teams in each conference
    standings['games'] = standings['W'] + standings ['L']
    standings['Tm'] = standings['Tm'].str.replace('[^\w\s]+','').str.replace('\d+\s*$','').str.strip()
    standings = standings.replace({'Tm':teams}, regex=True)

    if year < 2003:   # if year is < 2003 replace CHA with CHH. ugly but it works!
        standings['Tm'].replace('CHO','CHH', inplace=True)
    standings = standings.drop(['W','L'], axis=1)
    df_merge = pd.merge(stats, standings, on='Tm', how='left')
    
    if not voting.empty:
        voting['Tm'] = voting['Tm'].str.strip()
        voting = voting.loc[:,['Player','Tm','Share','Rank']]
        df_merge = pd.merge(df_merge, voting, on=['Player','Tm'], how='left')
        df_merge['got_votes'] = (df_merge['Share'] > 0).astype(int)
        df_merge['is_mvp'] = (df_merge['Rank'] == 1).astype(int)
        df_merge['Share'].fillna(0, inplace=True)
    else:
        df_merge['is_mvp'] = np.nan
        df_merge['got_votes'] = np.nan
        df_merge['Share']= np.nan
    df_merge['gp_pct'] = df_merge['G'] / df_merge['games']
    df_merge = df_merge.drop(['G','games'], axis=1)
    if data.empty:
        data = df_merge
    else:
        data = pd.concat([data,df_merge])

data = data.sort_values('Share', ascending=False)
data['Share'] = data['Share'].map(lambda x: '{0:.3}'.format(x))
data['TS%'] = data['TS%'].map(lambda x: '{0:.3}'.format(x))
data['W/L%'] = data['W/L%'].map(lambda x: '{0:.3}'.format(x))
data['gp_pct'] = data['gp_pct'].map(lambda x: '{0:.3}'.format(x))
data=data.set_index('Player')
data['Share']=data.Share.astype('float')
data['TS%']=data['TS%'].astype('float')
data['W/L%']=data['W/L%'].astype('float')
data['gp_pct']=data['gp_pct'].astype('float')

all_data=data[data.columns]

# output to csv
outdir = os.path.join(os.getcwd(),'output')
if not os.path.exists(outdir):
    print(f"Creating directory \'{outdir}\'")
    os.makedirs(outdir)
all_data.to_csv(outdir + '/full_dataframe.csv', float_format='%.1f')

all_data
# Out:
# /Users/crazyforcandy1234/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:100: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                        Age   Tm    MP   TRB   AST  STL  BLK   PTS   FGA  \
# Player
# Stephen Curry           27  GSW  34.2   5.4   6.7  2.1  0.2  30.1  20.2
# LeBron James            28  MIA  37.9   8.0   7.3  1.7  0.9  26.8  17.8
# Shaquille O'Neal        27  LAL  40.0  13.6   3.8  0.5  3.0  29.7  21.1
# Kevin Garnett           27  MIN  39.4  13.9   5.0  1.5  2.2  24.2  19.6
# Michael Jordan          32  CHI  37.7   6.6   4.3  2.2  0.5  30.4  22.6
# Kevin Durant            25  OKC  38.5   7.4   5.5  1.3  0.7  32.0  20.8
# LeBron James            25  CLE  39.0   7.3   8.6  1.6  1.0  29.7  20.1
# Derrick Rose            22  CHI  37.4   4.1   7.7  1.0  0.6  25.0  19.7
# LeBron James            24  CLE  37.7   7.6   7.2  1.7  1.1  28.4  19.9
# James Harden            28  HOU  35.4   5.4   8.8  1.8  0.7  30.4  20.1
# Michael Jordan          28  CHI  38.8   6.4   6.1  2.3  0.9  30.1  22.7
# Michael Jordan          34  CHI  38.8   5.8   3.5  1.7  0.5  28.7  23.1
# Michael Jordan          27  CHI  37.0   6.0   5.5  2.7  1.0  31.5  22.4
# Stephen Curry           26  GSW  32.7   4.3   7.7  2.0  0.2  23.8  16.8
# Allen Iverson           25  PHI  42.0   3.8   4.6  2.5  0.3  31.1  25.5
# Giannis Antetokounmpo   24  MIL  33.0  12.6   6.0  1.3  1.4  27.0  17.1
# LeBron James            27  MIA  37.5   7.9   6.2  1.9  0.8  27.1  18.9
# Dirk Nowitzki           28  DAL  36.2   8.9   3.4  0.7  0.8  24.6  17.2
# Hakeem Olajuwon         31  HOU  41.0  11.9   3.6  1.6  3.7  27.3  21.2
# Russell Westbrook       28  OKC  34.6  10.7  10.4  1.6  0.4  31.6  24.0
# Kobe Bryant             29  LAL  38.9   6.3   5.4  1.8  0.5  28.3  20.6
# David Robinson          29  SAS  38.0  10.8   2.9  1.7  3.2  27.6  18.4
# Karl Malone             33  UTA  36.6   9.9   4.5  1.4  0.6  27.4  19.2
# Charles Barkley         29  PHO  37.6  12.2   5.1  1.6  1.0  25.6  18.1
# Steve Nash              30  PHO  34.3   3.3  11.5  1.0  0.1  15.5  11.4
# Michael Jordan          33  CHI  37.9   5.9   4.3  1.7  0.5  29.6  23.1
# Charlie Ward           0.404   ...    1999  11.1  0.540         1     8
# David Wesley           0.446   ...    1999  11.8  0.520         0     9
# Jason Williams         0.374   ...    1999  11.0  0.540         1     7
# Jayson Williams        0.445   ...    1999  15.9  0.320         0    14
# Corliss Williamson     0.485   ...    1999   6.2  0.540         1     7
# Kevin Willis           0.418   ...    1999  11.3  0.460         0    10
# Haywoode Workman       0.429   ...    1999  10.5  0.560         1     7
# Shareef Abdur-Rahim    0.465   ...    2000  15.6  0.268         0    12
# Ray Allen              0.455   ...    2000   9.7  0.512         1     8
# Derek Anderson         0.438   ...    2000   9.0  0.183         0    14
# Kenny Anderson         0.440   ...    2000   9.6  0.427         0    10
# Nick Anderson          0.391   ...    2000   7.9  0.537         1     8
# Cody Zeller            0.551   ...    2019  10.5  0.448         0    10
#
#                        Share  Rank  got_votes  is_mvp  gp_pct
# Player
# Stephen Curry          1.000   1.0          1       1   0.963
# LeBron James           0.998   1.0          1       1   0.927
# Shaquille O'Neal       0.998   1.0          1       1   0.963
# Kevin Garnett          0.991   1.0          1       1   1.000
# Michael Jordan         0.986   1.0          1       1   1.000
# Kevin Durant           0.986   1.0          1       1   0.988
# LeBron James           0.980   1.0          1       1   0.927
# Derrick Rose           0.977   1.0          1       1   0.988
# LeBron James           0.969   1.0          1       1   0.988
# James Harden           0.955   1.0          1       1   0.878
# Michael Jordan         0.938   1.0          1       1   0.976
# Michael Jordan         0.934   1.0          1       1   1.000
# Michael Jordan         0.928   1.0          1       1   1.000
# Stephen Curry          0.922   1.0          1       1   0.976
# Allen Iverson          0.904   1.0          1       1   0.866
# Giannis Antetokounmpo  0.903   1.0          1       1   0.925
# LeBron James           0.888   1.0          1       1   0.939
# Dirk Nowitzki          0.882   1.0          1       1   0.951
# Hakeem Olajuwon        0.880   1.0          1       1   0.976
# Russell Westbrook      0.879   1.0          1       1   0.988
# Kobe Bryant            0.873   1.0          1       1   1.000
# David Robinson         0.858   1.0          1       1   0.988
# Karl Malone            0.857   1.0          1       1   1.000
# Charles Barkley        0.852   1.0          1       1   0.927
# Steve Nash             0.839   1.0          1       1   0.915
# Michael Jordan         0.832   2.0          1       0   1.000
# Michael Jordan         0.831   1.0          1       1   1.000
# Shaquille O'Neal       0.813   2.0          1       0   0.890
# Tim Duncan             0.808   1.0          1       1   0.988
# Steve Nash             0.785   2.0          1       0   0.927
# ...                      ...   ...        ...     ...     ...
# Joe Smith              0.000   NaN          0       0   0.860
# Rik Smits              0.000   NaN          0       0   0.980
# Eric Snow              0.000   NaN          0       0   0.960
# Latrell Sprewell       0.000   NaN          0       0   0.740
# Jerry Stackhouse       0.000   NaN          0       0   0.840
# John Starks            0.000   NaN          0       0   1.000
# Bryant Stith           0.000   NaN          0       0   0.920
# John Stockton          0.000   NaN          0       0   1.000
# Damon Stoudamire       0.000   NaN          0       0   1.000
# Rod Strickland         0.000   NaN          0       0   0.880
# Maurice Taylor         0.000   NaN          0       0   0.920
# Otis Thorpe            0.000   NaN          0       0   0.980
# Gary Trent             0.000   NaN          0       0   0.900
# Keith Van Horn         0.000   NaN          0       0   0.840
# Shandon Anderson       0.000   NaN          0       0   1.000
# Antoine Walker         0.000   NaN          0       0   0.840
# Ben Wallace            0.000   NaN          0       0   0.920
# Charlie Ward           0.000   NaN          0       0   1.000
# David Wesley           0.000   NaN          0       0   1.000
# Jason Williams         0.000   NaN          0       0   1.000
# Jayson Williams        0.000   NaN          0       0   0.600
# Corliss Williamson     0.000   NaN          0       0   1.000
# Kevin Willis           0.000   NaN          0       0   0.840
# Haywoode Workman       0.000   NaN          0       0   0.580
# Shareef Abdur-Rahim    0.000   NaN          0       0   1.000
# Ray Allen              0.000   NaN          0       0   1.000
# Derek Anderson         0.000   NaN          0       0   0.780
# Kenny Anderson         0.000   NaN          0       0   1.000
# Nick Anderson          0.000   NaN          0       0   0.878
# Cody Zeller            0.000   NaN          0       0   0.731
#
# [4663 rows x 38 columns]

# %%
"""
THIS DATASET HAS 31 YEARS OF PLAYER STATS
(CURRENTLY FOR ALL NBA PLAYERS WHO PLAYED AN AVERAGE OF 25 MINUTES PER GAME, ~ TOP 150 PLAYERS FOR MINS PLAYED PER GAME EACH SEASON)
THE STATS INCLUDED ARE BOTH PER-GAME STATS, AS IN HOW MANY POINTS OR ASSISTS THE PLAYER SCORED ON AVERAGE PER GAME,
AS WELL AS ADVANCED STATS LIKE WIN SHARE (WS) AND VORP (VALUE OVER REPLACEMENT).
ALSO INCLUDED ARE THE PLAYER'S TEAM STATS FOR THAT SEASON: WIN/LOSE % AND SEED.
FINALLY, WE HAVE 3 VARIABLES OF MVP DATA: IS_MVP (BINARY, 1 IF MVP), GOT_VOTES (1 IF GOT VOTES), AND SHARE (VOTE SHARE)

I WILL TRAIN VARIOUS COMBINATIONS OF PERGAME, ADVANCED, TEAM STATS TO PREDICT THE 3 MVP OUTCOME VARIABLES.

I'LL TAKE 2019 OUT OF THE TRAIN DATA BECAUSE THERE IS NO OUTCOME YET.

BEFORE WE START ANY REGRESSIONS A GOOD WAY TO KICK OFF IS BY LOOKING AT CORRELATIONS BETWEEN EACH VARIABLE & VOTE SHARE

I WILL ADD OTHER NBA AWARD DATA, AS WELL AS ALL-STAR SELECTION

WILL CONDUCT RDD ANALYSIS FOR ALL PLAYERS THAT GOT VOTES WITH IS_MVP AS THE CUTOFF VALUES

"""
# Out:
# Index(['Player', 'Age', 'Tm', 'PER', 'TS%', 'USG%', 'VORP', 'WS'], dtype='object')

# %%
# Subset df 2000-2019 which includes player leader data (can only access 2000-2019 with bball reference web scraper)

directory = os.path.join(os.getcwd(),'season_leaders')
leaders = [pd.read_csv(f'./season_leaders/season_leaders_{year}.csv') for year in range(2000,2020)]
year=2000
for df in leaders:
    df["year"]=year
    year+=1
leaders=pd.concat(leaders).set_index('player').rename(index=str, columns={"year": "Year"})
leaders.index=leaders.index.rename("Player")
leaders["pra"]=leaders["point_lead_count_wins"]+leaders["rebound_lead_count_wins"]+leaders["assist_lead_count_wins"]
leaders["total_pra"]=leaders["point_lead_count_total"]+leaders["rebound_lead_count_total"]+leaders["rebound_lead_count_total"]
leaders["total_prank"]=leaders["total_pra"].rank(ascending=False)
leaders["pra_rank"] = leaders["pra"].rank(ascending=False) 

all_data_2000 = all_data[all_data["Year"]>=2000]
all_data_2000 = all_data_2000.merge(leaders,how='inner',on=['Player','Year'])

# output to csv
outdir = os.path.join(os.getcwd(),'output')
if not os.path.exists(outdir):
    print(f"Creating directory \'{outdir}\'")
    os.makedirs(outdir)
all_data_2000.to_csv(outdir + '/full_df_leaderdata.csv', float_format='%.1f')

all_data_2000
# Out:
#                        Age   Tm    MP   TRB   AST  STL  BLK   PTS   FGA  \
# Player
# Stephen Curry           27  GSW  34.2   5.4   6.7  2.1  0.2  30.1  20.2
# LeBron James            28  MIA  37.9   8.0   7.3  1.7  0.9  26.8  17.8
# Shaquille O'Neal        27  LAL  40.0  13.6   3.8  0.5  3.0  29.7  21.1
# Kevin Garnett           27  MIN  39.4  13.9   5.0  1.5  2.2  24.2  19.6
# Kevin Durant            25  OKC  38.5   7.4   5.5  1.3  0.7  32.0  20.8
# LeBron James            25  CLE  39.0   7.3   8.6  1.6  1.0  29.7  20.1
# Derrick Rose            22  CHI  37.4   4.1   7.7  1.0  0.6  25.0  19.7
# LeBron James            24  CLE  37.7   7.6   7.2  1.7  1.1  28.4  19.9
# James Harden            28  HOU  35.4   5.4   8.8  1.8  0.7  30.4  20.1
# Stephen Curry           26  GSW  32.7   4.3   7.7  2.0  0.2  23.8  16.8
# Allen Iverson           25  PHI  42.0   3.8   4.6  2.5  0.3  31.1  25.5
# Giannis Antetokounmpo   24  MIL  33.0  12.6   6.0  1.3  1.4  27.0  17.1
# LeBron James            27  MIA  37.5   7.9   6.2  1.9  0.8  27.1  18.9
# Dirk Nowitzki           28  DAL  36.2   8.9   3.4  0.7  0.8  24.6  17.2
# Russell Westbrook       28  OKC  34.6  10.7  10.4  1.6  0.4  31.6  24.0
# Kobe Bryant             29  LAL  38.9   6.3   5.4  1.8  0.5  28.3  20.6
# Steve Nash              30  PHO  34.3   3.3  11.5  1.0  0.1  15.5  11.4
# Shaquille O'Neal        32  MIA  34.1  10.4   2.7  0.5  2.3  22.9  15.0
# Tim Duncan              26  SAS  39.3  12.9   3.9  0.7  2.9  23.3  17.2
# Steve Nash              32  PHO  35.3   3.5  11.6  0.8  0.1  18.6  12.8
# Tim Duncan              25  SAS  40.6  12.7   3.7  0.7  2.5  25.5  18.3
# James Harden            27  HOU  36.4   8.1  11.2  1.5  0.5  29.1  18.9
# Steve Nash              31  PHO  35.4   4.2  10.5  0.8  0.2  18.8  13.4
# Kevin Durant            23  OKC  38.6   8.0   3.5  1.3  1.2  28.0  19.7
# Kevin Garnett           26  MIN  40.5  13.4   6.0  1.4  1.6  23.0  18.1
# LeBron James            33  CLE  36.9   8.6   9.1  1.4  0.9  27.5  19.3
# James Harden            25  HOU  36.8   5.7   7.0  1.9  0.7  27.4  18.1
# LeBron James            29  MIA  37.7   6.9   6.3  1.6  0.3  27.1  17.6
# Kevin Durant           0.503    ...                        19.0
# LeBron James           0.503    ...                        16.0
# Derrick Rose           0.445    ...                        12.0
# LeBron James           0.489    ...                        11.0
# James Harden           0.449    ...                        10.0
# Stephen Curry          0.487    ...                         6.0
# Allen Iverson          0.420    ...                        18.0
# Giannis Antetokounmpo  0.580    ...                        13.0
# LeBron James           0.531    ...                         8.0
# Dirk Nowitzki          0.502    ...                        10.0
# Russell Westbrook      0.425    ...                        30.0
# Kobe Bryant            0.459    ...                        24.0
# Steve Nash             0.502    ...                         1.0
# Shaquille O'Neal       0.601    ...                        11.0
# Tim Duncan             0.513    ...                        17.0
# Steve Nash             0.532    ...                         4.0
# Tim Duncan             0.508    ...                        22.0
# James Harden           0.440    ...                        20.0
# Steve Nash             0.512    ...                         7.0
# Kevin Durant           0.496    ...                         8.0
# Kevin Garnett          0.502    ...                        25.0
# LeBron James           0.542    ...                        24.0
# James Harden           0.440    ...                        14.0
# LeBron James           0.567    ...                        16.0
# Jason Kidd             0.391    ...                         8.0
# Chris Paul             0.488    ...                        10.0
# ...                      ...    ...                         ...
# Sam Cassell            0.466    ...                         4.0
# Cedric Ceballos        0.446    ...                        10.0
# Doug Christie          0.407    ...                         2.0
# Derrick Coleman        0.456    ...                         8.0
# Antonio Davis          0.440    ...                         2.0
# Michael Dickerson      0.436    ...                        17.0
# Charles Barkley        0.477    ...                         1.0
# Vlade Divac            0.503    ...                         1.0
# Howard Eisley          0.418    ...                         0.0
# Mario Elie             0.427    ...                         0.0
# Patrick Ewing          0.466    ...                         4.0
# Jamie Feick            0.428    ...                         0.0
# Steve Francis          0.445    ...                        22.0
# Kendall Gill           0.414    ...                         3.0
# Horace Grant           0.444    ...                         0.0
# Adrian Griffin         0.424    ...                         1.0
# Tom Gugliotta          0.481    ...                         3.0
# Anfernee Hardaway      0.474    ...                         9.0
# Tim Hardaway           0.386    ...                         2.0
# Ron Harper             0.399    ...                         0.0
# Othella Harrington     0.506    ...                         9.0
# Brent Barry            0.463    ...                         1.0
# Vin Baker              0.455    ...                         5.0
# Shandon Anderson       0.473    ...                         2.0
# Shareef Abdur-Rahim    0.465    ...                        23.0
# Ray Allen              0.455    ...                        15.0
# Derek Anderson         0.438    ...                        19.0
# Kenny Anderson         0.440    ...                         4.0
# Nick Anderson          0.391    ...                         2.0
# Cody Zeller            0.551    ...                         2.0
#
#                        rebound_lead_count_losses  assist_lead_count_losses  \
# Player
# Stephen Curry                                0.0                       3.0
# LeBron James                                 9.0                      11.0
# Shaquille O'Neal                            10.0                       3.0
# Kevin Garnett                               21.0                      10.0
# Kevin Durant                                 6.0                      10.0
# LeBron James                                 6.0                      14.0
# Derrick Rose                                 0.0                      16.0
# LeBron James                                 5.0                      11.0
# James Harden                                 0.0                      12.0
# Stephen Curry                                0.0                      12.0
# Allen Iverson                                1.0                       3.0
# Giannis Antetokounmpo                       15.0                       7.0
# LeBron James                                 7.0                      10.0
# Dirk Nowitzki                                9.0                       3.0
# Russell Westbrook                           19.0                      33.0
# Cedric Ceballos                          15.0                       0.0
# Doug Christie                             4.0                      21.0
# Derrick Coleman                          19.0                       3.0
# Antonio Davis                             5.0                       0.0
# Michael Dickerson                        28.0                       2.0
# Charles Barkley                           3.0                       5.0
# Vlade Divac                               5.0                       5.0
# Howard Eisley                             1.0                       8.0
# Mario Elie                                0.0                       2.0
# Patrick Ewing                             9.0                       1.0
# Jamie Feick                               0.0                       0.0
# Steve Francis                            33.0                      51.0
# Kendall Gill                              7.0                       5.0
# Horace Grant                              1.0                       3.0
# Adrian Griffin                            1.0                       6.0
# Tom Gugliotta                             5.0                       0.0
# Anfernee Hardaway                        19.0                      14.0
# Tim Hardaway                              5.0                      40.0
# Ron Harper                                0.0                      12.0
# Othella Harrington                        9.0                       1.0
# Brent Barry                               1.0                       4.0
# Vin Baker                                13.0                       0.0
# Shandon Anderson                         11.0                       4.0
# Shareef Abdur-Rahim                      30.0                       8.0
# Ray Allen                                30.0                       9.0
# Derek Anderson                           21.0                      11.0
# Kenny Anderson                            8.0                      37.0
# Nick Anderson                             3.0                       2.0
# Cody Zeller                               2.0                       0.0
#
#                        assist_lead_count_total    pra  total_pra  total_prank  \
# Player
# Stephen Curry                              9.0   88.0      121.0        208.0
# LeBron James                              44.0  120.0      163.0         50.0
# Shaquille O'Neal                          70.0  129.0      103.0        326.0
# Kevin Garnett                             74.0  102.0      102.0        334.5
# Kevin Durant                              22.0   90.0      137.0        119.0
# LeBron James                              23.0  119.0      196.0          7.0
# Derrick Rose                               2.0   95.0      188.0         14.5
# LeBron James                              26.0  121.0      181.0         22.0
# James Harden                               7.0   90.0      156.0         66.5
# Stephen Curry                              1.0   89.0      170.0         39.0
# Allen Iverson                              3.0   61.0       96.0        377.0
# Giannis Antetokounmpo                     54.0  102.0      118.0        225.5
# LeBron James                              20.0   58.0       96.0        377.0
# Dirk Nowitzki                             40.0   79.0       75.0        549.5
# Russell Westbrook                         52.0  118.0      227.0          1.0
# Kobe Bryant                                9.0   75.0      150.0         83.5
# Steve Nash                                 1.0   63.0      149.0         87.5
# Shaquille O'Neal                          43.0   52.0       42.0       1088.5
# Tim Duncan                                63.0  103.0      101.0        343.5
# Steve Nash                                 0.0   64.0      154.0         71.5
# Tim Duncan                                68.0  112.0      118.0        225.5
# James Harden                              30.0  114.0      217.0          2.0
# Steve Nash                                 1.0   58.0      147.0         96.0
# Kevin Durant                              24.0   52.0       57.0        784.5
# Kevin Garnett                             69.0  103.0      130.0        148.0
# LeBron James                              34.0  110.0      215.0          3.0
# James Harden                              14.0  101.0      180.0         24.0
# LeBron James                              32.0   89.0      141.0        108.0
# Jason Kidd                                25.0   79.0      176.0         31.0
# Chris Paul                                 0.0   73.0      187.0         17.0
# ...                                        ...    ...        ...          ...
# Sam Cassell                                3.0   52.0      156.0         66.5
# Cedric Ceballos                           17.0   14.0       15.0       2279.5
# Doug Christie                              2.0   12.0       46.0        976.0
# Derrick Coleman                           27.0   31.0       25.0       1667.5
# Antonio Davis                             28.0   17.0        5.0       3692.0
# Michael Dickerson                          0.0   12.0       32.0       1397.5
# Charles Barkley                           12.0    8.0       13.0       2436.5
# Vlade Divac                               21.0   16.0       15.0       2279.5
# Howard Eisley                              0.0    7.0       17.0       2129.5
# Mario Elie                                 0.0    1.0        4.0       3990.0
# Patrick Ewing                             32.0   27.0       11.0       2642.5
# Jamie Feick                               43.0   15.0        0.0       6409.0
# Steve Francis                              5.0   35.0      135.0        127.0
# Kendall Gill                               0.0    4.0       17.0       2129.5
# Horace Grant                              20.0   14.0        7.0       3239.0
# Adrian Griffin                            11.0   10.0       13.0       2436.5
# Tom Gugliotta                             21.0   16.0        5.0       3692.0
# Anfernee Hardaway                         12.0   25.0       47.0        953.0
# Tim Hardaway                               1.0   32.0       85.0        454.0
# Ron Harper                                 0.0    9.0       24.0       1714.0
# Othella Harrington                        15.0    7.0       11.0       2642.5
# Brent Barry                                4.0    4.0        9.0       2919.5
# Vin Baker                                 25.0   22.0       13.0       2436.5
# Shandon Anderson                           6.0   15.0       19.0       1995.0
# Shareef Abdur-Rahim                       52.0   23.0       46.0        976.0
# Ray Allen                                  3.0   21.0       48.0        933.5
# Derek Anderson                             4.0    3.0       43.0       1059.5
# Kenny Anderson                             1.0   18.0       82.0        486.5
# Nick Anderson                              1.0    4.0        7.0       3239.0
# Cody Zeller                               15.0    7.0        2.0       4863.0
#
#                        pra_rank
# Player
# Stephen Curry              20.0
# LeBron James                3.0
# Shaquille O'Neal            1.0
# Kevin Garnett              11.5
# Kevin Durant               16.5
# LeBron James                4.0
# Derrick Rose               14.5
# LeBron James                2.0
# James Harden               16.5
# Stephen Curry              18.5
# Allen Iverson             126.5
# Giannis Antetokounmpo      11.5
# LeBron James              153.5
# Dirk Nowitzki              35.5
# Russell Westbrook           5.0
# Kobe Bryant                51.5
# Steve Nash                107.0
# Shaquille O'Neal          219.0
# Tim Duncan                  9.5
# Steve Nash                101.5
# Tim Duncan                  7.0
# James Harden                6.0
# Steve Nash                153.5
# Kevin Durant              219.0
# Kevin Garnett               9.5
# LeBron James                8.0
# James Harden               13.0
# LeBron James               18.5
# Jason Kidd                 35.5
# Chris Paul                 58.5
# ...                         ...
# Sam Cassell               219.0
# Cedric Ceballos          1608.0
# Doug Christie            1811.5
# Derrick Coleman           631.5
# Antonio Davis            1377.0
# Michael Dickerson        1811.5
# Charles Barkley          2394.5
# Vlade Divac              1451.5
# Howard Eisley            2603.5
# Mario Elie               5338.0
# Patrick Ewing             775.5
# Jamie Feick              1527.5
# Steve Francis             527.0
# Kendall Gill             3489.5
# Horace Grant             1608.0
# Adrian Griffin           2045.0
# Tom Gugliotta            1451.5
# Anfernee Hardaway         865.5
# Tim Hardaway              599.0
# Ron Harper               2207.0
# Othella Harrington       2603.5
# Brent Barry              3489.5
# Vin Baker                1023.5
# Shandon Anderson         1527.5
# Shareef Abdur-Rahim       961.5
# Ray Allen                1086.0
# Derek Anderson           3932.0
# Kenny Anderson           1295.0
# Nick Anderson            3489.5
# Cody Zeller              2603.5
#
# [2969 rows x 51 columns]
